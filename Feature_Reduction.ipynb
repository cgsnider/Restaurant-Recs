# %% [markdown]
# <a href="https://colab.research.google.com/github/cgsnider/Restaurant-Recs/blob/main/Feature_Reduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_selection import VarianceThreshold
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
X = [[0, 2, 0, 3], [0, 1, 4, 3], [0, 1, 1, 3]]

att = pd.read_json("/content/drive/MyDrive/yelp_academic_dataset_restaurant_att (1).json")
#rest = pd.read_json("/content/drive/MyDrive/yelp_academic_dataset_restaurant.json")

# %%
#print(test)
selector = VarianceThreshold(threshold=(0.99))
#selector.fit_transform(test)
print(att)
#print(test)

# %%
cor = att.corr()

plt.figure(figsize=(24,20))
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
cor_target = abs(cor["stars"])
relevant_features = cor_target[cor_target>0.07]

# %%
print(relevant_features)
# Out:
# stars                         1.000000
# review_count                  0.148816
# street                        0.251847
# businessacceptscreditcards    0.074985
# restaurantsdelivery           0.157321
# bikeparking                   0.135601
# outdoorseating                0.124111
# restaurantsreservations       0.166919
# hastv                         0.089114
# caters                        0.135810
# intimate                      0.070611
# hipster                       0.081199
# classy                        0.136981
# trendy                        0.104077
# casual                        0.144445
# restaurantsgoodforgroups      0.078837
# Name: stars, dtype: float64
