# %%
# https://www.kaggle.com/mrmorj/restaurant-recommendation-challenge?select=orders.csv
# Which methods for feature selection? (manual, forwrad seleciton, backward selection)
# PCA or feature selection. Which one comes first? lightFM?
# m1 m2 m3 stuffs (3 different approaches?)
#https://www.kaggle.com/fahadsyed97/us-restaurants-post-covid-uncleaned-dataset
#https://www.kaggle.com/yelp-dataset/yelp-dataset?select=yelp_academic_dataset_review.json

# %%
from google.colab import files

upload = files.upload()
# Out:
#      <input type="file" id="files-90a0d684-f467-4808-8f15-a01c6531e233" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90a0d684-f467-4808-8f15-a01c6531e233">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving items.csv to items.csv

# %%
import pandas as pd

dataframe = pd.read_csv("/content/items.csv")

# %%
dataframe
# Out:
#                                          address             categories/0  \
# 0          110 Marietta St NW, Atlanta, GA 30303      American restaurant
# 1       123 Luckie St NW #108, Atlanta, GA 30303        Creole restaurant
# 2              678 10th St NW, Atlanta, GA 30318               Restaurant
# 3            930 Spring St NW, Atlanta, GA 30309     Fast food restaurant
# 4  950 W Peachtree St NW #215, Atlanta, GA 30309  New American restaurant
# 5             87 Poplar St NW, Atlanta, GA 30303         Pizza restaurant
# 6            240 Peachtree St, Atlanta, GA 30303   Fine dining restaurant
# 7            133 Luckie St NW, Atlanta, GA 30303      American restaurant
# 8            181 Peachtree St, Atlanta, GA 30303               Restaurant
# 9          300 Marietta St NW, Atlanta, GA 30313         Pizza restaurant
#
#            categories/1         categories/2        categories/3  \
# 0            Restaurant                  NaN                 NaN
# ...

# %%
dataframe.columns
# Out:
# Index(['address', 'categories/0', 'categories/1', 'categories/2',
#        'categories/3', 'categories/4', 'categories/5', 'categories/6',
#        'categoryName', 'cid', 'city', 'countryCode', 'isAdvertisement',
#        'locatedIn', 'location/lat', 'location/lng', 'menu', 'neighborhood',
#        'orderBy/0/name', 'orderBy/0/url', 'permanentlyClosed', 'phone',
#        'placeId', 'plusCode', 'postalCode', 'price', 'rank', 'reviewsCount',
#        'reviewsDistribution/fiveStar', 'reviewsDistribution/fourStar',
#        'reviewsDistribution/oneStar', 'reviewsDistribution/threeStar',
#        'reviewsDistribution/twoStar', 'scrapedAt', 'searchPageUrl',
#        'searchString', 'state', 'street', 'subTitle', 'temporarilyClosed',
#        'title', 'totalScore', 'url', 'website'],
#       dtype='object')

# %% [markdown]
# useful features:
#
# - delivery distan
# - Location
# - Price
# - Hours of service (currently Closed or Open)
# - Food they serve (food category)
# - Reviews
# - Diversity of food
# - Revenue (maybe)
# - Weather conditions based on location
# - Delivery distance
# - Rate (mean, median scores)
# -
