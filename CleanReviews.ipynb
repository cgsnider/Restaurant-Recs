# %%
import pandas as pd
import json

# %%
##IMPORTANT: only run this cell if you are missing data/cleaned/yelp_academic_dataset_review.json
## Runtime ~4.5 minutes and requires >32GB of memory/swap space
business_df = pd.read_json('data/cleaned/yelp_academic_dataset_restaurant.json')

cols = ["review_id", "user_id", "business_id", "stars"]
data = []
file_name = 'data/yelp_reviews/yelp_academic_dataset_review.json'

with open(file_name, encoding='latin-1') as f:
    for line in f:
        doc = json.loads(line)
        lst = [doc[col] for col in cols]
        data.append(lst)

review_df = pd.DataFrame(data=data, columns=cols)


review_df = review_df[review_df['business_id'].isin(business_df['business_id'])]
review_df.to_json("data/cleaned/yelp_academic_dataset_review.json")

# %%
review_df = pd.read_json('data/cleaned/yelp_academic_dataset_review.json')

# %%
review_df
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 9        pUycOfUwM8vqX7KjRRhUEA  59MxRhNVhU9MYndMkz0wtw
# 11       l3Wk_mvAog6XANIuGQ9C7Q  ZbqSHbgCjzVAqaa7NKWn5A
# ...                         ...                     ...
# 6990270  7NgXAuTFiJHYbuepOPwU0w  x1QLCwZGFAjxRRw4EHc3-g
# 6990272  wD5ZWao_vjyT2h4xmGam8Q  7L7GL5Pi2cf8mbm2Dpw4zw
# 6990274  YVX1Wsa4LYxjvFwuHBb_gA  RKPkxOYQlM0BjhM-H6_vAw
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3
# 2        YjUWPpI6HXG530lwP-fb2A      3
# 3        kxX2SOes4o-D3ZQBkiMRfA      5
# 9        gebiRewfieSdtt17PTW6Zg      3
# 11       EQ-TZ2eeD_E0BHuvoaeG5Q      4
# ...                         ...    ...
# ...

# %%
business_df = pd.read_json('data/cleaned/yelp_academic_dataset_restaurant.json')
business_df
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA       Perkiomen Valley Brewery
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150328  1jx1sfgjgVg0nM6n3p0xWA           Savaya Coffee Market
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
#
#                     address             city state postal_code   latitude  \
# 3               935 Race St     Philadelphia    PA       19107  39.955505
# ...

# %%
cleaned_review = pd.read_json('data/cleaned/yelp_academic_dataset_review.json')
cleaned_review
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 9        pUycOfUwM8vqX7KjRRhUEA  59MxRhNVhU9MYndMkz0wtw
# 11       l3Wk_mvAog6XANIuGQ9C7Q  ZbqSHbgCjzVAqaa7NKWn5A
# ...                         ...                     ...
# 6990270  7NgXAuTFiJHYbuepOPwU0w  x1QLCwZGFAjxRRw4EHc3-g
# 6990272  wD5ZWao_vjyT2h4xmGam8Q  7L7GL5Pi2cf8mbm2Dpw4zw
# 6990274  YVX1Wsa4LYxjvFwuHBb_gA  RKPkxOYQlM0BjhM-H6_vAw
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3
# 2        YjUWPpI6HXG530lwP-fb2A      3
# 3        kxX2SOes4o-D3ZQBkiMRfA      5
# 9        gebiRewfieSdtt17PTW6Zg      3
# 11       EQ-TZ2eeD_E0BHuvoaeG5Q      4
# ...                         ...    ...
# ...

# %%
cleaned_review[cleaned_review.]
